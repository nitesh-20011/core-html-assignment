# %% [markdown]
# # core html Assignment 4

# %%
#  Build a simple blog web page with 3 pages home, web development, and web design. Each page must contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information. For the home page you can add some information about yourself


<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>Home</title>
</head>
<body>

  <!-- Navigation Menu -->
  <nav>
    <a href="home.html">Home</a> |
    <a href="web-development.html">Web Development</a> |
    <a href="web-design.html">Web Design</a>
  </nav>

  <h1>Welcome to My Blog</h1>
  <p>Hello! I'm a passionate web developer learning HTML, CSS, and JavaScript to build amazing websites.</p>

  <h2>Ordered List of HTML Tags</h2>
  <ol>
    <li><strong>&lt;html&gt;</strong> - Root element of an HTML page.</li>
    <li><strong>&lt;head&gt;</strong> - Contains meta information and title.</li>
    <li><strong>&lt;body&gt;</strong> - Contains the main content of the page.</li>
    <li><strong>&lt;p&gt;</strong> - Defines a paragraph.</li>
    <li><strong>&lt;a&gt;</strong> - Defines a hyperlink.</li>
  </ol>

  <h2>Full Stack Web Development Tech Stack</h2>
  <dl>
    <dt>HTML</dt>
    <dd>Used to structure web content.</dd>

    <dt>CSS</dt>
    <dd>Used for styling and designing web pages.</dd>

    <dt>JavaScript</dt>
    <dd>Adds interactivity to web pages.</dd>

    <dt>Node.js</dt>
    <dd>Allows JavaScript to run on the server-side.</dd>

    <dt>MongoDB</dt>
    <dd>NoSQL database used for storing application data.</dd>
  </dl>

  <h2>Ordered List of Tech Stacks with Tables</h2>

  <ol>
    <li>HTML
      <table border="1">
        <tr>
          <th>Tech Stack</th>
          <th>Primary Use Cases</th>
          <th>Key Features</th>
        </tr>
        <tr>
          <td>HTML</td>
          <td>Structuring content on the web</td>
          <td>Simple, Flexible, Supported Everywhere</td>
        </tr>
      </table>
    </li>

    <li>CSS
      <table border="1">
        <tr>
          <th>Tech Stack</th>
          <th>Primary Use Cases</th>
          <th>Key Features</th>
        </tr>
        <tr>
          <td>CSS</td>
          <td>Styling and designing web pages</td>
          <td>Responsive design, Animations, Styling</td>
        </tr>
      </table>
    </li>

    <li>JavaScript
      <table border="1">
        <tr>
          <th>Tech Stack</th>
          <th>Primary Use Cases</th>
          <th>Key Features</th>
        </tr>
        <tr>
          <td>JavaScript</td>
          <td>Adding interactivity and functionality</td>
          <td>Dynamic content, Event handling, APIs</td>
        </tr>
      </table>
    </li>
  </ol>

</body>
</html>

# %%
# Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag

<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>Web Development</title>
</head>
<body>

  <!-- Navigation Menu -->
  <nav>
    <a href="home.html">Home</a> |
    <a href="web-development.html">Web Development</a> |
    <a href="web-design.html">Web Design</a>
  </nav>

  <h1>Web Development</h1>
  <p>Web development involves building and maintaining websites. It includes front-end development (HTML, CSS, JavaScript) and back-end development (databases, servers, APIs).</p>

</body>
</html>

# %%
#  Create a description list of full stack web development tech stack, using the <dl> tag. Each term should be a tech stack name and each description should be a brief explanation of what the tech stack is used for

<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <title>Web Design - My Blog</title>
</head>
<body>

  <!-- Navigation Menu -->
  <nav>
    <a href="home.html">Home</a> |
    <a href="web-development.html">Web Development</a> |
    <a href="web-design.html">Web Design</a>
  </nav>

  <!-- Main Content -->
  <h1>Web Design</h1>
  <p>Web design focuses on the visual appearance and user experience of a website. It includes choosing color schemes, typography, layout, and graphic elements to ensure the site is both attractive and easy to use.</p>

</body>
</html>

# %%
# Create a table to display a conference schedule. Each row corresponds to a time slot, and each column corresponds to a room. Some time slots might have multiple sessions running simultaneously in different rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule. (use table attribute “cellpadding”  to give extra padding in each table cell )


<!DOCTYPE html>
<html>
<head>
    <title>Class Timetable</title>
    <style>
        table {
            width: 80%;
            border-collapse: collapse;
            text-align: center;
            margin: 20px auto;
        }
        th, td {
            border: 1px solid #444;
            padding: 10px;
        }
        th {
            background-color: #ef0505;
        }
        caption {
            font-size: 1.5em;
            margin-bottom: 10px;
        }
    </style>
</head>
<body>

    <table>
        <tr>
            <th colspan="5">Timetable</th>
        </tr>
        <tr>
            <td rowspan="6">ABCD</td>

        </tr>
        <tr>
            <td>S</td>
            <td>S</td>
            <td>S</td>
            <td>S</td>
        </tr>
        <tr>
            <td>S</td>
            <td>S</td>
            <td>S</td>
            <td>S</td>
        </tr>
        <tr>
            <td colspan="4">Lunch</td>
        </tr>
        <tr>
            <td>S</td>
            <td>S</td>
            <td>S</td>
            <td rowspan="2" >D</td>
        </tr>
        <tr>

            <td>S</td>
            <td>S</td>
            <td>S</td>


        </tr>
    </table>

</body>
</html>
